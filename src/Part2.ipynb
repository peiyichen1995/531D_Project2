# %%
import Part2,Part1
import tool
budgets, queries, bids=tool.readData('../data/ds2.pkl')
print(budgets.shape,queries.shape,bids.shape)
Part2.LPOnlineAdWord(budgets, queries, bids,0,1)
# Out:
# (20,) (400,) (20, 400)
# Compute an optimal fractional solution alpha*,beta* to the LP
# ----------------------------------------------------
# 20
# /usr/local/anaconda3/lib/python3.8/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Status: Optimal
# {'B0': alpha_B0, 'B1': alpha_B1, 'B2': alpha_B2, 'B3': alpha_B3, 'B4': alpha_B4, 'B5': alpha_B5, 'B6': alpha_B6, 'B7': alpha_B7, 'B8': alpha_B8, 'B9': alpha_B9, 'B10': alpha_B10, 'B11': alpha_B11, 'B12': alpha_B12, 'B13': alpha_B13, 'B14': alpha_B14, 'B15': alpha_B15, 'B16': alpha_B16, 'B17': alpha_B17, 'B18': alpha_B18, 'B19': alpha_B19}
# alpha_B11 = 1.0
# alpha_B12 = 1.0
# alpha_B13 = 1.0
# alpha_B14 = 1.0
# alpha_B15 = 1.0
# alpha_B16 = 1.0
# alpha_B18 = 1.0
# alpha_B19 = 1.0
# alpha_B3 = 1.0
# alpha_B6 = 1.0
# alpha_B7 = 1.0
# alpha_B8 = 1.0
# beta_0 = 1.07
# beta_1 = 0.96
# beta_10 = 0.9
# beta_100 = 0.93
# beta_101 = 0.87
# beta_102 = 1.03
# beta_103 = 1.04
# beta_104 = 0.89
# beta_105 = 1.04
# beta_106 = 0.82
# beta_107 = 1.03
# beta_108 = 0.98
# beta_109 = 0.84
# beta_11 = 0.93
# beta_110 = 0.91
# beta_111 = 0.99
# beta_112 = 1.08
# beta_113 = 1.02
# beta_114 = 1.09
# beta_115 = 1.13
# beta_116 = 0.85
# beta_117 = 1.07
# beta_118 = 1.01
# beta_119 = 0.97
# beta_12 = 0.84
# beta_120 = 0.9
# beta_121 = 0.94
# beta_122 = 1.08
# beta_123 = 1.08
# beta_124 = 1.09
# beta_125 = 1.08
# beta_126 = 0.94
# beta_127 = 1.07
# beta_128 = 0.94
# beta_129 = 1.01
# beta_13 = 1.05
# beta_130 = 0.86
# beta_131 = 0.89
# beta_132 = 0.94
# beta_133 = 0.96
# beta_134 = 1.06
# beta_135 = 0.91
# beta_136 = 0.93
# beta_137 = 0.88
# beta_138 = 1.17
# beta_139 = 1.06
# beta_14 = 1.04
# beta_140 = 0.88
# beta_141 = 0.89
# beta_142 = 0.95
# beta_143 = 1.12
# beta_144 = 1.04
# beta_145 = 0.93
# beta_146 = 1.0
# beta_147 = 1.05
# beta_148 = 0.97
# beta_149 = 0.95
# beta_15 = 0.96
# beta_150 = 1.11
# beta_151 = 0.91
# beta_152 = 0.98
# beta_153 = 0.82
# beta_154 = 0.98
# beta_155 = 1.16
# beta_156 = 1.08
# beta_157 = 1.16
# beta_158 = 0.82
# beta_159 = 1.04
# beta_16 = 1.05
# beta_160 = 1.19
# beta_161 = 1.1
# beta_162 = 1.03
# beta_163 = 1.0
# beta_164 = 0.94
# beta_165 = 0.91
# beta_166 = 1.0
# beta_167 = 0.93
# beta_168 = 1.04
# beta_169 = 1.04
# beta_17 = 1.05
# beta_170 = 0.85
# beta_171 = 0.89
# beta_172 = 1.1
# beta_173 = 1.09
# beta_174 = 0.98
# beta_175 = 1.07
# beta_176 = 0.95
# beta_177 = 0.98
# beta_178 = 0.85
# beta_179 = 0.98
# beta_18 = 0.97
# beta_180 = 1.02
# beta_181 = 0.73
# beta_182 = 1.0
# beta_183 = 1.03
# beta_184 = 0.78
# beta_185 = 1.01
# beta_186 = 1.09
# beta_187 = 1.01
# beta_188 = 0.89
# beta_189 = 1.13
# beta_19 = 0.96
# beta_190 = 0.94
# beta_191 = 0.96
# beta_192 = 0.92
# beta_193 = 1.0
# beta_194 = 0.78
# beta_195 = 0.87
# beta_196 = 0.98
# beta_197 = 1.0
# beta_198 = 1.05
# beta_199 = 0.98
# beta_2 = 1.12
# beta_20 = 0.97
# beta_21 = 0.94
# beta_22 = 0.92
# beta_23 = 0.9
# beta_24 = 0.96
# beta_25 = 1.16
# beta_26 = 1.04
# beta_27 = 0.9
# beta_28 = 0.95
# beta_29 = 1.01
# beta_3 = 0.97
# beta_30 = 1.0
# beta_31 = 1.24
# beta_32 = 0.87
# beta_33 = 0.89
# beta_34 = 0.85
# beta_35 = 1.11
# beta_36 = 1.0
# beta_37 = 0.97
# beta_38 = 0.98
# beta_39 = 1.05
# beta_4 = 1.0
# beta_5 = 0.92
# beta_6 = 0.97
# beta_60 = 1.3
# beta_61 = 0.94
# beta_62 = 1.02
# beta_63 = 1.01
# beta_64 = 0.9
# beta_65 = 0.96
# beta_66 = 1.04
# beta_67 = 1.02
# beta_68 = 0.99
# beta_69 = 0.87
# beta_7 = 0.71
# beta_70 = 0.8
# beta_71 = 0.94
# beta_72 = 1.1
# beta_73 = 1.16
# beta_74 = 1.08
# beta_75 = 0.9
# beta_76 = 0.95
# beta_77 = 0.91
# beta_78 = 0.86
# beta_79 = 1.1
# beta_8 = 1.06
# beta_9 = 1.05
# Total Revenue =  397.4500000000002
# ----------------------------------------------------
# ({}, 228.56)
